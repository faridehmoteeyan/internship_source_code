# %%
import pandas as pd

# %%
tips = pd.read_csv("D:\\python\\note_during_learning\\pandas\\tips.csv")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
for tip in tips:
    print(tip)
# Out:
# total_bill
# tip
# sex
# smoker
# day
# time
# size

# %%
for tip in tips.values:
    print(tip)
# Out:
# [16.99 1.01 'Female' 'No' 'Sun' 'Dinner' 2]
# [10.34 1.66 'Male' 'No' 'Sun' 'Dinner' 3]
# [21.01 3.5 'Male' 'No' 'Sun' 'Dinner' 3]
# [23.68 3.31 'Male' 'No' 'Sun' 'Dinner' 2]
# [24.59 3.61 'Female' 'No' 'Sun' 'Dinner' 4]
# [25.29 4.71 'Male' 'No' 'Sun' 'Dinner' 4]
# [8.77 2.0 'Male' 'No' 'Sun' 'Dinner' 2]
# [26.88 3.12 'Male' 'No' 'Sun' 'Dinner' 4]
# [15.04 1.96 'Male' 'No' 'Sun' 'Dinner' 2]
# [14.78 3.23 'Male' 'No' 'Sun' 'Dinner' 2]
# [10.27 1.71 'Male' 'No' 'Sun' 'Dinner' 2]
# [35.26 5.0 'Female' 'No' 'Sun' 'Dinner' 4]
# [15.42 1.57 'Male' 'No' 'Sun' 'Dinner' 2]
# [18.43 3.0 'Male' 'No' 'Sun' 'Dinner' 4]
# [14.83 3.02 'Female' 'No' 'Sun' 'Dinner' 2]
# [21.58 3.92 'Male' 'No' 'Sun' 'Dinner' 2]
# [10.33 1.67 'Female' 'No' 'Sun' 'Dinner' 3]
# [16.29 3.71 'Male' 'No' 'Sun' 'Dinner' 3]
# [16.97 3.5 'Female' 'No' 'Sun' 'Dinner' 3]
# [20.65 3.35 'Male' 'No' 'Sat' 'Dinner' 3]
# [17.92 4.08 'Male' 'No' 'Sat' 'Dinner' 2]
# [20.29 2.75 'Female' 'No' 'Sat' 'Dinner' 2]
# ...

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
tips[['total_bill', 'tip']].mean()
# Out:
# total_bill    19.785943
# tip            2.998279
# dtype: float64

# %%
tips.describe()
#به معنی صدکه این 25 و50 و75
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %% [markdown]
# ### groupby

# %%
tips.groupby(["sex"]).mean()
# Out:
#         total_bill       tip      size
# sex
# Female   18.056897  2.833448  2.459770
# Male     20.744076  3.089618  2.630573

# %%
tips.groupby(["sex",'size']).describe()
# Out:
#             total_bill                                                        \
#                  count       mean       std    min      25%     50%      75%
# sex    size
# Female 1           3.0   6.796667  3.521950   3.07   5.1600   7.250   8.6600
#        2          58.0  15.339483  4.798400   5.75  12.3025  14.415  17.5000
#        3          14.0  21.547143  9.100667  10.33  16.5850  17.610  24.5075
#        4           9.0  30.278889  7.257022  20.69  24.5900  30.140  34.8300
#        5           1.0  29.850000       NaN  29.85  29.8500  29.850  29.8500
#        6           2.0  28.425000  1.944544  27.05  27.7375  28.425  29.1125
# Male   1           1.0   8.580000       NaN   8.58   8.5800   8.580   8.5800
#        2          98.0  17.104082  6.608159   7.25  12.5550  15.750  20.4400
#        3          24.0  24.287083  9.625980  10.34  17.5075  21.915  28.6700
#        4          28.0  28.078214  9.054547  16.49  20.5100  25.725  32.9625
# ...

# %% [markdown]
# #### lambada in groupby

# %%
#its not usefull if 2 clomuns include filter
tips.groupby('sex').filter(lambda k : k['tip'].mean() > 1.0).mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20712\2613179393.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   tips.groupby('sex').filter(lambda k : k['tip'].mean() > 1.0).mean()
# total_bill    19.785943
# tip            2.998279
# size           2.569672
# dtype: float64

# %%
a =tips.groupby('sex').filter(lambda k : k['tip'].mean() > 2.0).groupby('sex').mean()

# %% [markdown]
# ###  pivot_table

# %%
a =pd.pivot_table(tips,'tip',['sex','size'],['day', 'time'])
a.groupby("size")

# %%
tips.columns().mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 tips.columns().mean()
#
# TypeError: 'Index' object is not callable
