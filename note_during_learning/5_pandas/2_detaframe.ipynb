# %%
import pandas as pd

# %% [markdown]
# ### tail.head

# %%
tips = pd.read_csv('tips.csv')
tips.head()#show 5 first rows
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %% [markdown]
# ### slicing

# %%
# if we don't use list it gives us a seri not df
tips['smoker']
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#       ...
# 239     No
# 240    Yes
# 241    Yes
# 242     No
# 243     No
# Name: smoker, Length: 244, dtype: object

# %%
tips[['smoker']]
# Out:
#     smoker
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
# ..     ...
# 239     No
# 240    Yes
# 241    Yes
# 242     No
# 243     No
#
# [244 rows x 1 columns]

# %%
# for more than 2 column use []
tips[['sex' ,'smoker' ,'day']]
# Out:
#         sex smoker   day
# 0    Female     No   Sun
# 1      Male     No   Sun
# 2      Male     No   Sun
# 3      Male     No   Sun
# 4    Female     No   Sun
# ..      ...    ...   ...
# 239    Male     No   Sat
# 240  Female    Yes   Sat
# 241    Male    Yes   Sat
# 242    Male     No   Sat
# 243  Female     No  Thur
#
# [244 rows x 3 columns]

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### inplace & drop

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# when we use drop it shows the outpot.but there us no change in main file
#to make this change we can use another var
tipsy = tips.drop(['day'],axis=1)
tipsy.head()
# Out:
#    total_bill   tip     sex smoker    time  size
# 0       16.99  1.01  Female     No  Dinner     2
# 1       10.34  1.66    Male     No  Dinner     3
# 2       21.01  3.50    Male     No  Dinner     3
# 3       23.68  3.31    Male     No  Dinner     2
# 4       24.59  3.61  Female     No  Dinner     4

# %%
# or inplace=true
tips.drop(['tip'],axis=1, inplace = True)

# %%
tips.head()
# Out:
#    total_bill     sex smoker  day    time  size
# 0       16.99  Female     No  Sun  Dinner     2
# 1       10.34    Male     No  Sun  Dinner     3
# 2       21.01    Male     No  Sun  Dinner     3
# 3       23.68    Male     No  Sun  Dinner     2
# 4       24.59  Female     No  Sun  Dinner     4

# %%
#the real .csv dos;nt change
tips = pd.read_csv('tips.csv')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
pd.DataFrame.to_csv(tipsy,'tipsy.csv')

# %% [markdown]
# ### Iterate on a dataframes

# %%
total_bill_tip = tips[['total_bill','tip']]
total_bill_tip.head()
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66
# 2       21.01  3.50
# 3       23.68  3.31
# 4       24.59  3.61

# %%
for total_bill,tip  in total_bill_tip.values:
    print(total_bill+tip)
# Out:
# 18.0
# 12.0
# 24.51
# 26.99
# 28.2
# 30.0
# 10.77
# 30.0
# 17.0
# 18.009999999999998
# 11.98
# 40.26
# 16.99
# 21.43
# 17.85
# 25.5
# 12.0
# 20.0
# 20.47
# 24.0
# 22.0
# 23.04
# 18.0
# 47.0
# 23.0
# 20.15
# 15.37
# 14.69
# 26.0
# 22.65
# 11.0
# 20.85
# 18.060000000000002
# 23.14
# 21.05
# 27.66
# 18.31
# 20.0
# 21.0
# 36.269999999999996
# 18.28
# 20.0
# 17.0
# 11.0
# 36.0
# 21.29
# 27.23
# 38.4
# 30.6
# 21.04
# 15.04
# 12.889999999999999
# 40.010000000000005
# 11.5
# 29.9
# 23.0
# 41.01
# 27.91
# 13.0
# 55.0
# 23.5
# 15.81
# 13.0
# 22.049999999999997
# 20.23
# 23.229999999999997
# 18.919999999999998
# 4.07
# 22.240000000000002
# 17.1
# 13.99
# 20.07
# 30.0
# 30.28
# 16.93
# 11.76
# 21.0
# 31.2
# 25.76
# 20.0
# 22.44
# 20.06
# 11.9
# 37.68
# 18.01
# 40.0
# 15.03
# 22.28
# 30.560000000000002
# 24.16
# 31.97
# 25.99
# 6.75
# 20.62
# 26.0
# 44.900000000000006
# 31.28
# 13.53
# 24.01
# 13.96
# 13.85
# 18.380000000000003
# 46.8
# 25.900000000000002
# 25.0
# 17.0
# 24.549999999999997
# ...
