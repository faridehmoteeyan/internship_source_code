# %%
import pandas as pd

# %% [markdown]
# ### Challenge:
#  Open file 01_height... and convert male to 1 and female to 0
# * one time without pandas,one time with

# %%
files = open('01_heights_weights_genders.csv','r+').readlines()
column = files[0].strip()
del files[0]
files[:5]
# Out:
# ['"Male",73.847017017515,241.893563180437\n',
#  '"Male",68.7819040458903,162.310472521300\n',
#  '"Male",74.1101053917849,212.7408555565\n',
#  '"Male",71.7309784033377,220.042470303077\n',
#  '"Male",69.8817958611153,206.349800623871\n']

# %%
del files[0]
s=files[:5]

# %%
lst=[column]
for line in files:
    x= line.split(",")[0]
    if x == "\"Male\"":
        x=1
    elif x == '\"Female\"':
        x=0
    new = list((x,y,z))
    lst.append(new)

lst
# Out:
# ['"Gender","Height","Weight"',
#  [1, '61.9442458795172', '113.649102675312\n'],
#  [1, '61.9442458795172', '113.649102675312\n'],
#  [1, '61.9442458795172', '113.649102675312\n'],
#  [1, '61.9442458795172', '113.649102675312\n'],
#  [1, '61.9442458795172', '113.649102675312\n'],
#  [1, '61.9442458795172', '113.649102675312\n'],
#  [1, '61.9442458795172', '113.649102675312\n'],
#  [1, '61.9442458795172', '113.649102675312\n'],
#  [1, '61.9442458795172', '113.649102675312\n'],
#  [1, '61.9442458795172', '113.649102675312\n'],
#  [1, '61.9442458795172', '113.649102675312\n'],
#  [1, '61.9442458795172', '113.649102675312\n'],
#  [1, '61.9442458795172', '113.649102675312\n'],
#  [1, '61.9442458795172', '113.649102675312\n'],
#  [1, '61.9442458795172', '113.649102675312\n'],
#  [1, '61.9442458795172', '113.649102675312\n'],
#  [1, '61.9442458795172', '113.649102675312\n'],
#  [1, '61.9442458795172', '113.649102675312\n'],
#  [1, '61.9442458795172', '113.649102675312\n'],
# ...

# %% [markdown]
# ### with pandas

# %%
heights_weights_genders = pd.read_csv('01_heights_weights_genders.csv')
heights_weights_genders.tail()
# Out:
#       Gender     Height      Weight
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103

# %%
heights_weights_genders["Gender"]=[1 if i == "Male" else 0 for i in heights_weights_genders.Gender]
heights_weights_genders.head(30)
# Out:
#     Gender     Height      Weight
# 0        1  73.847017  241.893563
# 1        1  68.781904  162.310473
# 2        1  74.110105  212.740856
# 3        1  71.730978  220.042470
# 4        1  69.881796  206.349801
# 5        1  67.253016  152.212156
# 6        1  68.785081  183.927889
# 7        1  68.348516  167.971110
# 8        1  67.018950  175.929440
# 9        1  63.456494  156.399676
# 10       1  71.195382  186.604926
# 11       1  71.640805  213.741169
# 12       1  64.766329  167.127461
# 13       1  69.283070  189.446181
# 14       1  69.243732  186.434168
# 15       1  67.645620  172.186930
# 16       1  72.418317  196.028506
# 17       1  63.974326  172.883470
# 18       1  69.640060  185.983958
# 19       1  67.936005  182.426648
# 20       1  67.915050  174.115929
# 21       1  69.439440  197.731422
# 22       1  66.149132  149.173566
# 23       1  75.205974  228.761781
# 24       1  67.893196  162.006652
# 25       1  68.144033  192.343977
# ...

# %%
[for i in heights_weights_genders.Gender 1 if i == "Male"]
# Out:
#   Input In [15]
#     [for i in heights_weights_genders.Gender 1 if i == "Male"]
#      ^
# SyntaxError: invalid syntax

# %%
information = pd.read_csv('01_heights_weights_genders.csv')
information['Gender'] = [1 if gender == 'Male' else 0 for gender in information.Gender]
information.head()
# Out:
#    Gender     Height      Weight
# 0       1  73.847017  241.893563
# 1       1  68.781904  162.310473
# 2       1  74.110105  212.740856
# 3       1  71.730978  220.042470
# 4       1  69.881796  206.349801
