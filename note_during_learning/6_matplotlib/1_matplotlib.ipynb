# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
death_line = plt.figure()
line = plt.plot([0,1,2],[3,0,3],label="stright")
plt.xlabel("time")
plt.ylabel("limo",fontsize = 17)
plt.legend(loc = "best")
plt.title("limo during the time")
plt.show()

# %%
#save
fig_2 = plt.figure(figsize=(1,1))
plt.plot([1,2,3,4], [1,2,3,4],label = "green_line",color = 'g')
plt.title("title")
plt.legend()
plt.savefig("saving_1.png")

# %%
# load a image
from IPython.display import Image
Image("saving.png")

# %% [markdown]
# ### Colors, line styles and

# %%
x = np.linspace(0,10,100)
plt.plot(x, np.sin(x), color="b")
plt.plot(x, np.sin(x - 0), color='blue') # specify color by name
plt.plot(x, np.sin(x - 1), color='g') # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75') # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44') # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 and 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');
# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-') # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':'); # dotted

# %%
# its the most common way
# [color][marker][line]
plt.plot([1,2,3], [0,1,2] ,'^r')

# %% [markdown]
#     Other combinations such as ``[color][marker][line]`` are also
#     supported, but note that their parsing may be ambiguous.
#
#     **Markers**
#
#     =============    ===============================
#     character        description
#     =============    ===============================
#     ``'.'``          point marker
#     ``','``          pixel marker
#     ``'o'``          circle marker
#     ``'v'``          triangle_down marker
#     ``'^'``          triangle_up marker
#     ``'<'``          triangle_left marker
#     ``'>'``          triangle_right marker
#     ``'1'``          tri_down marker
#     ``'2'``          tri_up marker
#     ``'3'``          tri_left marker
#     ``'4'``          tri_right marker
#     ``'s'``          square marker
#     ``'p'``          pentagon marker
#     ``'*'``          star marker
#     ``'h'``          hexagon1 marker
#     ``'H'``          hexagon2 marker
#     ``'+'``          plus marker
#     ``'x'``          x marker
#     ``'D'``          diamond marker
#     ``'d'``          thin_diamond marker
#     ``'|'``          vline marker
#     ``'_'``          hline marker
#     =============    ===============================
#
#     **Line Styles**
#
#     =============    ===============================
#     character        description
#     =============    ===============================
#     ``'-'``          solid line style
#     ``'--'``         dashed line style
#     ``'-.'``         dash-dot line style
#     ``':'``          dotted line style
#     =============    ===============================
#
#     Example format strings::
#
#         'b'    # blue markers with default shape
#         'or'   # red circles
#         '-g'   # green solid line
#         '--'   # dashed line with default color
#         '^k:'  # black triangle_up markers connected by a dotted line
#
#     **Colors**
#
#     The supported color abbreviations are the single letter codes
#
#     =============    ===============================
#     character        color
#     =============    ===============================
#     ``'b'``          blue
#     ``'g'``          green
#     ``'r'``          red
#     ``'c'``          cyan
#     ``'m'``          magenta
#     ``'y'``          yellow
#     ``'k'``          black
#     ``'w'``          white
#     =============    ===============================

# %% [markdown]
# ### subplot,subplots

# %%
x = np.linspace(0,10,1000)
plt.figure()
plt.subplot(2,2,3) #(rows, columns, panel number)
plt.plot(x, np.sin(x))
plt.subplot(1, 2, 2 )
plt.plot(x, np.cos(x));

# %%
fig , ax = plt.subplots(2,2,figsize=(15,8))
ax[1,1].plot(x , np.sin(x))
ax[0,1].plot(x , np.sin(x))
ax[1,1].set_title("the plot")
# Out:
# Text(0.5, 1.0, 'the plot')

# %%
f, (ax1, ax2) = plt.subplots(1, 2)
ax1.plot(x, y)
ax1.set_title('Sharing Y axis')
ax2.scatter(x, y)
ax2.set_ylabel("noy")
ax2.set_axis_off()

# %%
! pip install sklearn
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 7.4/7.4 MB 721.7 kB/s eta 0:00:00
# ...
#      ------------------------------------ 298.0/298.0 kB 635.2 kB/s eta 0:00:00
# ...
#      -------------------------------------- 38.6/38.6 MB 969.4 kB/s eta 0:00:00
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1310 sha256=5109041717ccbae94f200da95f762dd7878bf53f38327df211de80019145957a
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\e4\7b\98\b6466d71b8d738a0c547008b9eb39bf8676d1ff6ca4b22af1c
# Successfully built sklearn
# ...

# %%
from sklearn.datasets import load_digits
digits = load_digits(n_class=6)

# %%
fig, ax = plt.subplots(8, 8, figsize=(6, 6))
for i, axi in enumerate(ax.flat):
    axi.imshow(digits.images[i], cmap='binary')
    axi.set_axis_off()#از بین بردن محور عمودی و افقی  پلات

# %% [markdown]
# ### scatter plot

# %% [markdown]
# The primary difference of plt.scatter from plt.plot is that it can be used to create
# scatter plots where the properties of each individual point (size, face color, edge color,
# etc.) can be individually controlled or mapped to data.

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000* rng.rand(100)
plt.scatter(x,y,c=colors,s=sizes,alpha=.5,cmap="Oranges_r")
plt.colorbar()

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T
targets = iris.target
# Out:
# 150

# %%
plt.scatter(features[0],features[1],s = features[3]*100, c=targets,  cmap='plasma',alpha=.5, label='size = third feature * 100')
plt.xlabel(iris.feature_names[0]+ ' | first feature')
plt.ylabel(iris.feature_names[1]+ ' | second feature')
plt.legend(fontsize=5)
plt.colorbar()

# %%
plt.colormaps()
# Out:
# ['magma',
#  'inferno',
#  'plasma',
#  'viridis',
#  'cividis',
#  'twilight',
#  'twilight_shifted',
#  'turbo',
#  'Blues',
#  'BrBG',
#  'BuGn',
#  'BuPu',
#  'CMRmap',
#  'GnBu',
#  'Greens',
#  'Greys',
#  'OrRd',
#  'Oranges',
#  'PRGn',
#  'PiYG',
#  'PuBu',
#  'PuBuGn',
#  'PuOr',
#  'PuRd',
#  'Purples',
#  'RdBu',
#  'RdGy',
#  'RdPu',
#  'RdYlBu',
#  'RdYlGn',
#  'Reds',
#  'Spectral',
#  'Wistia',
#  'YlGn',
#  'YlGnBu',
#  'YlOrBr',
#  'YlOrRd',
#  'afmhot',
#  'autumn',
#  'binary',
#  'bone',
#  'brg',
#  'bwr',
#  'cool',
#  'coolwarm',
#  'copper',
#  'cubehelix',
#  'flag',
#  'gist_earth',
#  'gist_gray',
#  'gist_heat',
#  'gist_ncar',
#  'gist_rainbow',
#  'gist_stern',
#  'gist_yarg',
#  'gnuplot',
#  'gnuplot2',
#  'gray',
#  'hot',
#  'hsv',
#  'jet',
#  'nipy_spectral',
#  'ocean',
#  'pink',
#  'prism',
#  'rainbow',
#  'seismic',
#  'spring',
#  'summer',
#  'terrain',
#  'winter',
#  'Accent',
#  'Dark2',
#  'Paired',
#  'Pastel1',
#  'Pastel2',
# ...

# %% [markdown]
# ###  Stack Bar Chart

# %%
height1 = np.array([10, 45, 30, 15, 50])
height2 = np.array([35, 15, 20, 15, 20])

plt.bar()

# %%
Score = np.array([20, 35, 30, 35, 27])
q = plt.figure(figsize=(5,2))
plt.bar([0,1,2,3,4],Score)
plt.show()
