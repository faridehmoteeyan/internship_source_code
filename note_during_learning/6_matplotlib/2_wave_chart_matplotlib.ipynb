# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
line = plt.figure()
plt.plot([0,1,2,3],[0,1,1,0],label="wave")
plt.xlabel()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 3>()
#       1 line = plt.figure()
#       2 plt.plot([0,1,2,3],[0,1,1,0],label="wave")
# ----> 3 plt.xlabel('J')
#
# TypeError: 'str' object is not callable
